# %% [markdown]
# # Style Transfer with Deep Neural Networks
#
#
# In this notebook, we’ll *recreate* a style transfer method that is outlined in the paper, [Image Style Transfer Using Convolutional Neural Networks, by Gatys](https://www.cv-foundation.org/openaccess/content_cvpr_2016/papers/Gatys_Image_Style_Transfer_CVPR_2016_paper.pdf) in PyTorch.
#
# In this paper, style transfer uses the features found in the 19-layer VGG Network, which is comprised of a series of convolutional and pooling layers, and a few fully-connected layers. In the image below, the convolutional layers are named by stack and their order in the stack. Conv_1_1 is the first convolutional layer that an image is passed through, in the first stack. Conv_2_1 is the first convolutional layer in the *second* stack. The deepest convolutional layer in the network is conv_5_4.
#
# <img src='notebook_ims/vgg19_convlayers.png' width=80% />
#
# ### Separating Style and Content
#
# Style transfer relies on separating the content and style of an image. Given one content image and one style image, we aim to create a new, _target_ image which should contain our desired content and style components:
# * objects and their arrangement are similar to that of the **content image**
# * style, colors, and textures are similar to that of the **style image**
#
# An example is shown below, where the content image is of a cat, and the style image is of [Hokusai's Great Wave](https://en.wikipedia.org/wiki/The_Great_Wave_off_Kanagawa). The generated target image still contains the cat but is stylized with the waves, blue and beige colors, and block print textures of the style image!
#
# <img src='notebook_ims/style_tx_cat.png' width=80% />
#
# In this notebook, we'll use a pre-trained VGG19 Net to extract content or style features from a passed in image. We'll then formalize the idea of content and style _losses_ and use those to iteratively update our target image until we get a result that we want. You are encouraged to use a style and content image of your own and share your work on Twitter with @udacity; we'd love to see what you come up with!

# %%
# !wget https://github.com/udacity/deep-learning-v2-pytorch/archive/master.zip
# Out:
# --2018-12-17 06:34:18--  https://github.com/udacity/deep-learning-v2-pytorch/archive/master.zip
# Resolving github.com (github.com)... 192.30.253.113, 192.30.253.112
# Connecting to github.com (github.com)|192.30.253.113|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://codeload.github.com/udacity/deep-learning-v2-pytorch/zip/master [following]
# --2018-12-17 06:34:18--  https://codeload.github.com/udacity/deep-learning-v2-pytorch/zip/master
# Resolving codeload.github.com (codeload.github.com)... 192.30.253.121, 192.30.253.120
# Connecting to codeload.github.com (codeload.github.com)|192.30.253.121|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [application/zip]
# Saving to: ‘master.zip.1’
#
# master.zip.1            [                <=> ]  99.05M  10.3MB/s    in 9.5s
#
# 2018-12-17 06:34:27 (10.5 MB/s) - ‘master.zip.1’ saved [103864314]

# %%
# !unzip master.zip.1;
# Out:
# Archive:  master.zip.1
# 388f43cc427dd324855d598b7a7618f341b28794
#    creating: deep-learning-v2-pytorch-master/
#  extracting: deep-learning-v2-pytorch-master/.gitignore
#   inflating: deep-learning-v2-pytorch-master/LICENSE
#   inflating: deep-learning-v2-pytorch-master/README.md
#    creating: deep-learning-v2-pytorch-master/attention/
#   inflating: deep-learning-v2-pytorch-master/attention/Attention_Basics.ipynb
#   inflating: deep-learning-v2-pytorch-master/attention/Attention_Basics_Solution.ipynb
#    creating: deep-learning-v2-pytorch-master/attention/images/
#   inflating: deep-learning-v2-pytorch-master/attention/images/Context_vector.png
#   inflating: deep-learning-v2-pytorch-master/attention/images/scoring_functions.png
#   inflating: deep-learning-v2-pytorch-master/attention/images/softmax.png
#    creating: deep-learning-v2-pytorch-master/autoencoder/
#    creating: deep-learning-v2-pytorch-master/autoencoder/convolutional-autoencoder/
#   inflating: deep-learning-v2-pytorch-master/autoencoder/convolutional-autoencoder/Convolutional_Autoencoder_Exercise.ipynb
#   inflating: deep-learning-v2-pytorch-master/autoencoder/convolutional-autoencoder/Convolutional_Autoencoder_Solution.ipynb
#   inflating: deep-learning-v2-pytorch-master/autoencoder/convolutional-autoencoder/Upsampling_Solution.ipynb
#    creating: deep-learning-v2-pytorch-master/autoencoder/convolutional-autoencoder/notebook_ims/
#   inflating: deep-learning-v2-pytorch-master/autoencoder/convolutional-autoencoder/notebook_ims/autoencoder_1.png
#   inflating: deep-learning-v2-pytorch-master/autoencoder/convolutional-autoencoder/notebook_ims/autoencoder_denoise.png
#   inflating: deep-learning-v2-pytorch-master/autoencoder/convolutional-autoencoder/notebook_ims/compressed.png
#   inflating: deep-learning-v2-pytorch-master/autoencoder/convolutional-autoencoder/notebook_ims/conv_enc_1.png
#   inflating: deep-learning-v2-pytorch-master/autoencoder/convolutional-autoencoder/notebook_ims/conv_enc_2.png
#   inflating: deep-learning-v2-pytorch-master/autoencoder/convolutional-autoencoder/notebook_ims/convolutional_autoencoder.png
#   inflating: deep-learning-v2-pytorch-master/autoencoder/convolutional-autoencoder/notebook_ims/denoising.png
#   inflating: deep-learning-v2-pytorch-master/autoencoder/convolutional-autoencoder/notebook_ims/mnist_examples.png
#    creating: deep-learning-v2-pytorch-master/autoencoder/denoising-autoencoder/
#   inflating: deep-learning-v2-pytorch-master/autoencoder/denoising-autoencoder/Denoising_Autoencoder_Exercise.ipynb
#   inflating: deep-learning-v2-pytorch-master/autoencoder/denoising-autoencoder/Denoising_Autoencoder_Solution.ipynb
#    creating: deep-learning-v2-pytorch-master/autoencoder/denoising-autoencoder/notebook_ims/
#   inflating: deep-learning-v2-pytorch-master/autoencoder/denoising-autoencoder/notebook_ims/autoencoder_1.png
#   inflating: deep-learning-v2-pytorch-master/autoencoder/denoising-autoencoder/notebook_ims/autoencoder_denoise.png
#   inflating: deep-learning-v2-pytorch-master/autoencoder/denoising-autoencoder/notebook_ims/compressed.png
#   inflating: deep-learning-v2-pytorch-master/autoencoder/denoising-autoencoder/notebook_ims/denoising.png
#   inflating: deep-learning-v2-pytorch-master/autoencoder/denoising-autoencoder/notebook_ims/mnist_examples.png
#    creating: deep-learning-v2-pytorch-master/autoencoder/linear-autoencoder/
#   inflating: deep-learning-v2-pytorch-master/autoencoder/linear-autoencoder/Simple_Autoencoder_Exercise.ipynb
#   inflating: deep-learning-v2-pytorch-master/autoencoder/linear-autoencoder/Simple_Autoencoder_Solution.ipynb
#    creating: deep-learning-v2-pytorch-master/autoencoder/linear-autoencoder/notebook_ims/
#   inflating: deep-learning-v2-pytorch-master/autoencoder/linear-autoencoder/notebook_ims/autoencoder_1.png
#   inflating: deep-learning-v2-pytorch-master/autoencoder/linear-autoencoder/notebook_ims/autoencoder_denoise.png
#   inflating: deep-learning-v2-pytorch-master/autoencoder/linear-autoencoder/notebook_ims/compressed.png
#   inflating: deep-learning-v2-pytorch-master/autoencoder/linear-autoencoder/notebook_ims/denoising.png
#   inflating: deep-learning-v2-pytorch-master/autoencoder/linear-autoencoder/notebook_ims/mnist_examples.png
#   inflating: deep-learning-v2-pytorch-master/autoencoder/linear-autoencoder/notebook_ims/simple_autoencoder.png
#    creating: deep-learning-v2-pytorch-master/batch-norm/
#   inflating: deep-learning-v2-pytorch-master/batch-norm/Batch_Normalization.ipynb
#    creating: deep-learning-v2-pytorch-master/convolutional-neural-networks/
#    creating: deep-learning-v2-pytorch-master/convolutional-neural-networks/cifar-cnn/
#   inflating: deep-learning-v2-pytorch-master/convolutional-neural-networks/cifar-cnn/cifar10_cnn_augmentation.ipynb
#   inflating: deep-learning-v2-pytorch-master/convolutional-neural-networks/cifar-cnn/cifar10_cnn_exercise.ipynb
#   inflating: deep-learning-v2-pytorch-master/convolutional-neural-networks/cifar-cnn/cifar10_cnn_solution.ipynb
#   inflating: deep-learning-v2-pytorch-master/convolutional-neural-networks/cifar-cnn/model_augmented.pt
#   inflating: deep-learning-v2-pytorch-master/convolutional-neural-networks/cifar-cnn/model_cifar.pt
#    creating: deep-learning-v2-pytorch-master/convolutional-neural-networks/cifar-cnn/notebook_ims/
#   inflating: deep-learning-v2-pytorch-master/convolutional-neural-networks/cifar-cnn/notebook_ims/2_layer_conv.png
#   inflating: deep-learning-v2-pytorch-master/convolutional-neural-networks/cifar-cnn/notebook_ims/cifar_data.png
#    creating: deep-learning-v2-pytorch-master/convolutional-neural-networks/conv-visualization/
#   inflating: deep-learning-v2-pytorch-master/convolutional-neural-networks/conv-visualization/conv_visualization.ipynb
#   inflating: deep-learning-v2-pytorch-master/convolutional-neural-networks/conv-visualization/custom_filters.ipynb
#    creating: deep-learning-v2-pytorch-master/convolutional-neural-networks/conv-visualization/data/
#   inflating: deep-learning-v2-pytorch-master/convolutional-neural-networks/conv-visualization/data/bridge_trees_example.jpg
#   inflating: deep-learning-v2-pytorch-master/convolutional-neural-networks/conv-visualization/data/curved_lane.jpg
#   inflating: deep-learning-v2-pytorch-master/convolutional-neural-networks/conv-visualization/data/sobel_ops.png
#   inflating: deep-learning-v2-pytorch-master/convolutional-neural-networks/conv-visualization/data/udacity_sdc.png
#   inflating: deep-learning-v2-pytorch-master/convolutional-neural-networks/conv-visualization/data/white_lines.jpg
#   inflating: deep-learning-v2-pytorch-master/convolutional-neural-networks/conv-visualization/maxpooling_visualization.ipynb
#    creating: deep-learning-v2-pytorch-master/convolutional-neural-networks/conv-visualization/notebook_ims/
#   inflating: deep-learning-v2-pytorch-master/convolutional-neural-networks/conv-visualization/notebook_ims/CNN_all_layers.png
#   inflating: deep-learning-v2-pytorch-master/convolutional-neural-networks/conv-visualization/notebook_ims/conv_layer.gif
#   inflating: deep-learning-v2-pytorch-master/convolutional-neural-networks/conv-visualization/notebook_ims/maxpooling_ex.png
#   inflating: deep-learning-v2-pytorch-master/convolutional-neural-networks/conv-visualization/notebook_ims/relu_ex.png
#   inflating: deep-learning-v2-pytorch-master/convolutional-neural-networks/conv-visualization/notebook_ims/sobel_ops.png
#    creating: deep-learning-v2-pytorch-master/convolutional-neural-networks/mnist-mlp/
#   inflating: deep-learning-v2-pytorch-master/convolutional-neural-networks/mnist-mlp/mnist_mlp_exercise.ipynb
#   inflating: deep-learning-v2-pytorch-master/convolutional-neural-networks/mnist-mlp/mnist_mlp_solution.ipynb
#   inflating: deep-learning-v2-pytorch-master/convolutional-neural-networks/mnist-mlp/mnist_mlp_solution_with_validation.ipynb
#   inflating: deep-learning-v2-pytorch-master/convolutional-neural-networks/mnist-mlp/model.pt
#    creating: deep-learning-v2-pytorch-master/cycle-gan/
#   inflating: deep-learning-v2-pytorch-master/cycle-gan/CycleGAN_Exercise.ipynb
#   inflating: deep-learning-v2-pytorch-master/cycle-gan/CycleGAN_Solution.ipynb
#   inflating: deep-learning-v2-pytorch-master/cycle-gan/helpers.py
#    creating: deep-learning-v2-pytorch-master/cycle-gan/notebook_images/
#   inflating: deep-learning-v2-pytorch-master/cycle-gan/notebook_images/CycleGAN_loss.png
#   inflating: deep-learning-v2-pytorch-master/cycle-gan/notebook_images/XY_season_images.png
#   inflating: deep-learning-v2-pytorch-master/cycle-gan/notebook_images/cycle_consistency_ex.png
#   inflating: deep-learning-v2-pytorch-master/cycle-gan/notebook_images/cyclegan_generator_ex.png
#   inflating: deep-learning-v2-pytorch-master/cycle-gan/notebook_images/discriminator_layers.png
#   inflating: deep-learning-v2-pytorch-master/cycle-gan/notebook_images/horse2zebra.jpg
#   inflating: deep-learning-v2-pytorch-master/cycle-gan/notebook_images/reconstruction_error.png
#   inflating: deep-learning-v2-pytorch-master/cycle-gan/notebook_images/resnet_50.png
#   inflating: deep-learning-v2-pytorch-master/cycle-gan/notebook_images/resnet_block.png
#  extracting: deep-learning-v2-pytorch-master/cycle-gan/notebook_images/sample-004000-summer2winter.png
#   inflating: deep-learning-v2-pytorch-master/cycle-gan/notebook_images/training_cycle_ex.png
#    creating: deep-learning-v2-pytorch-master/cycle-gan/samples_cyclegan/
#   inflating: deep-learning-v2-pytorch-master/cycle-gan/samples_cyclegan/samples_dir.txt
#    creating: deep-learning-v2-pytorch-master/dcgan-svhn/
#   inflating: deep-learning-v2-pytorch-master/dcgan-svhn/DCGAN_Exercise.ipynb
#   inflating: deep-learning-v2-pytorch-master/dcgan-svhn/DCGAN_Solution.ipynb
#    creating: deep-learning-v2-pytorch-master/dcgan-svhn/assets/
#  extracting: deep-learning-v2-pytorch-master/dcgan-svhn/assets/SVHN_examples.png
#   inflating: deep-learning-v2-pytorch-master/dcgan-svhn/assets/conv_discriminator.png
#   inflating: deep-learning-v2-pytorch-master/dcgan-svhn/assets/conv_generator.png
#   inflating: deep-learning-v2-pytorch-master/dcgan-svhn/assets/svhn_dcgan.png
#    creating: deep-learning-v2-pytorch-master/gan-mnist/
#   inflating: deep-learning-v2-pytorch-master/gan-mnist/MNIST_GAN_Exercise.ipynb
#   inflating: deep-learning-v2-pytorch-master/gan-mnist/MNIST_GAN_Solution.ipynb
#    creating: deep-learning-v2-pytorch-master/gan-mnist/assets/
#   inflating: deep-learning-v2-pytorch-master/gan-mnist/assets/gan_network.png
#   inflating: deep-learning-v2-pytorch-master/gan-mnist/assets/gan_pipeline.png
#   inflating: deep-learning-v2-pytorch-master/gan-mnist/assets/leaky_relu.png
#   inflating: deep-learning-v2-pytorch-master/gan-mnist/assets/tanh_fn.png
#    creating: deep-learning-v2-pytorch-master/intro-neural-networks/
#    creating: deep-learning-v2-pytorch-master/intro-neural-networks/gradient-descent/
#   inflating: deep-learning-v2-pytorch-master/intro-neural-networks/gradient-descent/GradientDescent.ipynb
#   inflating: deep-learning-v2-pytorch-master/intro-neural-networks/gradient-descent/GradientDescentSolutions.ipynb
#   inflating: deep-learning-v2-pytorch-master/intro-neural-networks/gradient-descent/data.csv
#    creating: deep-learning-v2-pytorch-master/intro-neural-networks/student-admissions/
#    creating: deep-learning-v2-pytorch-master/intro-neural-networks/student-admissions/.ipynb_checkpoints/
#   inflating: deep-learning-v2-pytorch-master/intro-neural-networks/student-admissions/.ipynb_checkpoints/StudentAdmissions-checkpoint.ipynb
#   inflating: deep-learning-v2-pytorch-master/intro-neural-networks/student-admissions/.ipynb_checkpoints/StudentAdmissionsSolutions-checkpoint.ipynb
#   inflating: deep-learning-v2-pytorch-master/intro-neural-networks/student-admissions/StudentAdmissions.ipynb
#   inflating: deep-learning-v2-pytorch-master/intro-neural-networks/student-admissions/StudentAdmissionsSolutions.ipynb
#   inflating: deep-learning-v2-pytorch-master/intro-neural-networks/student-admissions/student_data.csv
#    creating: deep-learning-v2-pytorch-master/intro-to-pytorch/
#   inflating: deep-learning-v2-pytorch-master/intro-to-pytorch/Part 1 - Tensors in PyTorch (Exercises).ipynb
#   inflating: deep-learning-v2-pytorch-master/intro-to-pytorch/Part 1 - Tensors in PyTorch (Solution).ipynb
#   inflating: deep-learning-v2-pytorch-master/intro-to-pytorch/Part 2 - Neural Networks in PyTorch (Exercises).ipynb
#   inflating: deep-learning-v2-pytorch-master/intro-to-pytorch/Part 2 - Neural Networks in PyTorch (Solution).ipynb
#   inflating: deep-learning-v2-pytorch-master/intro-to-pytorch/Part 3 - Training Neural Networks (Exercises).ipynb
#   inflating: deep-learning-v2-pytorch-master/intro-to-pytorch/Part 3 - Training Neural Networks (Solution).ipynb
#   inflating: deep-learning-v2-pytorch-master/intro-to-pytorch/Part 4 - Fashion-MNIST (Exercises).ipynb
#   inflating: deep-learning-v2-pytorch-master/intro-to-pytorch/Part 4 - Fashion-MNIST (Solution).ipynb
#   inflating: deep-learning-v2-pytorch-master/intro-to-pytorch/Part 5 - Inference and Validation (Exercises).ipynb
#   inflating: deep-learning-v2-pytorch-master/intro-to-pytorch/Part 5 - Inference and Validation (Solution).ipynb
#   inflating: deep-learning-v2-pytorch-master/intro-to-pytorch/Part 6 - Saving and Loading Models.ipynb
#   inflating: deep-learning-v2-pytorch-master/intro-to-pytorch/Part 7 - Loading Image Data (Exercises).ipynb
#   inflating: deep-learning-v2-pytorch-master/intro-to-pytorch/Part 7 - Loading Image Data (Solution).ipynb
#   inflating: deep-learning-v2-pytorch-master/intro-to-pytorch/Part 8 - Transfer Learning (Exercises).ipynb
#   inflating: deep-learning-v2-pytorch-master/intro-to-pytorch/Part 8 - Transfer Learning (Solution).ipynb
#   inflating: deep-learning-v2-pytorch-master/intro-to-pytorch/README.md
#    creating: deep-learning-v2-pytorch-master/intro-to-pytorch/assets/
#   inflating: deep-learning-v2-pytorch-master/intro-to-pytorch/assets/ImageNet_example.png
#   inflating: deep-learning-v2-pytorch-master/intro-to-pytorch/assets/Pooling_Simple_max.png
#   inflating: deep-learning-v2-pytorch-master/intro-to-pytorch/assets/activation.png
#   inflating: deep-learning-v2-pytorch-master/intro-to-pytorch/assets/autoencoder_1.png
#   inflating: deep-learning-v2-pytorch-master/intro-to-pytorch/assets/backprop_diagram.png
#   inflating: deep-learning-v2-pytorch-master/intro-to-pytorch/assets/cat.70.jpg
#   inflating: deep-learning-v2-pytorch-master/intro-to-pytorch/assets/cat_cropped.png
#   inflating: deep-learning-v2-pytorch-master/intro-to-pytorch/assets/conv_net.jpg
#   inflating: deep-learning-v2-pytorch-master/intro-to-pytorch/assets/dog.128.jpg
#   inflating: deep-learning-v2-pytorch-master/intro-to-pytorch/assets/dog_cat.png
#  extracting: deep-learning-v2-pytorch-master/intro-to-pytorch/assets/examples_new.png
#   inflating: deep-learning-v2-pytorch-master/intro-to-pytorch/assets/fashion-mnist-sprite.png
#   inflating: deep-learning-v2-pytorch-master/intro-to-pytorch/assets/full_padding_no_strides_transposed.gif
#   inflating: deep-learning-v2-pytorch-master/intro-to-pytorch/assets/function_approx.png
#   inflating: deep-learning-v2-pytorch-master/intro-to-pytorch/assets/gradient_descent.png
#   inflating: deep-learning-v2-pytorch-master/intro-to-pytorch/assets/image_distribution.png
#   inflating: deep-learning-v2-pytorch-master/intro-to-pytorch/assets/infographic.pdf
#   inflating: deep-learning-v2-pytorch-master/intro-to-pytorch/assets/lenet.png
#   inflating: deep-learning-v2-pytorch-master/intro-to-pytorch/assets/mlp_mnist.png
#   inflating: deep-learning-v2-pytorch-master/intro-to-pytorch/assets/mnist.png
#   inflating: deep-learning-v2-pytorch-master/intro-to-pytorch/assets/multilayer_diagram_weights.png
#   inflating: deep-learning-v2-pytorch-master/intro-to-pytorch/assets/network_diagram.png
#   inflating: deep-learning-v2-pytorch-master/intro-to-pytorch/assets/overfitting.png
#   inflating: deep-learning-v2-pytorch-master/intro-to-pytorch/assets/padding_strides.gif
#   inflating: deep-learning-v2-pytorch-master/intro-to-pytorch/assets/simple_neuron.png
#   inflating: deep-learning-v2-pytorch-master/intro-to-pytorch/assets/tensor_examples.svg
#   inflating: deep-learning-v2-pytorch-master/intro-to-pytorch/assets/test_examples.png
#   inflating: deep-learning-v2-pytorch-master/intro-to-pytorch/assets/train_examples.png
#   inflating: deep-learning-v2-pytorch-master/intro-to-pytorch/assets/w1_backprop_graph.png
#   inflating: deep-learning-v2-pytorch-master/intro-to-pytorch/fc_model.py
#   inflating: deep-learning-v2-pytorch-master/intro-to-pytorch/helper.py
#    creating: deep-learning-v2-pytorch-master/keras/
#    creating: deep-learning-v2-pytorch-master/keras/IMDB-keras/
#   inflating: deep-learning-v2-pytorch-master/keras/IMDB-keras/IMDB_In_Keras.ipynb
#   inflating: deep-learning-v2-pytorch-master/keras/IMDB-keras/IMDB_In_Keras_Solutions.ipynb
#    creating: deep-learning-v2-pytorch-master/keras/cifar10-augmentation/
#   inflating: deep-learning-v2-pytorch-master/keras/cifar10-augmentation/aug_model.weights.best.hdf5
#   inflating: deep-learning-v2-pytorch-master/keras/cifar10-augmentation/cifar10_augmentation.ipynb
#    creating: deep-learning-v2-pytorch-master/keras/cifar10-classification/
#   inflating: deep-learning-v2-pytorch-master/keras/cifar10-classification/MLP.weights.best.hdf5
#   inflating: deep-learning-v2-pytorch-master/keras/cifar10-classification/cifar10_cnn.ipynb
#   inflating: deep-learning-v2-pytorch-master/keras/cifar10-classification/cifar10_mlp.ipynb
#   inflating: deep-learning-v2-pytorch-master/keras/cifar10-classification/model.weights.best.hdf5
#    creating: deep-learning-v2-pytorch-master/keras/mnist-mlp/
#   inflating: deep-learning-v2-pytorch-master/keras/mnist-mlp/mnist.model.best.hdf5
#   inflating: deep-learning-v2-pytorch-master/keras/mnist-mlp/mnist_mlp.ipynb
#    creating: deep-learning-v2-pytorch-master/keras/student-admissions-keras/
#   inflating: deep-learning-v2-pytorch-master/keras/student-admissions-keras/StudentAdmissionsKeras.ipynb
#   inflating: deep-learning-v2-pytorch-master/keras/student-admissions-keras/student_data.csv
#    creating: deep-learning-v2-pytorch-master/keras/transfer-learning/
#   inflating: deep-learning-v2-pytorch-master/keras/transfer-learning/bottleneck_features.ipynb
#    creating: deep-learning-v2-pytorch-master/keras/transfer-learning/bottleneck_features/
#  extracting: deep-learning-v2-pytorch-master/keras/transfer-learning/bottleneck_features/.gitignore
#   inflating: deep-learning-v2-pytorch-master/keras/transfer-learning/dogvgg16.weights.best.hdf5
#    creating: deep-learning-v2-pytorch-master/keras/transfer-learning/figures/
#   inflating: deep-learning-v2-pytorch-master/keras/transfer-learning/figures/vgg16.png
#   inflating: deep-learning-v2-pytorch-master/keras/transfer-learning/figures/vgg16_transfer.png
#    creating: deep-learning-v2-pytorch-master/keras/transfer-learning/images/
#   inflating: deep-learning-v2-pytorch-master/keras/transfer-learning/images/American_water_spaniel_00648.jpg
#   inflating: deep-learning-v2-pytorch-master/keras/transfer-learning/images/Brittany_02625.jpg
#   inflating: deep-learning-v2-pytorch-master/keras/transfer-learning/images/Curly-coated_retriever_03896.jpg
#   inflating: deep-learning-v2-pytorch-master/keras/transfer-learning/images/Labrador_retriever_06449.jpg
#   inflating: deep-learning-v2-pytorch-master/keras/transfer-learning/images/Labrador_retriever_06455.jpg
#   inflating: deep-learning-v2-pytorch-master/keras/transfer-learning/images/Labrador_retriever_06457.jpg
#   inflating: deep-learning-v2-pytorch-master/keras/transfer-learning/images/Welsh_springer_spaniel_08203.jpg
#   inflating: deep-learning-v2-pytorch-master/keras/transfer-learning/images/sopa.jpg
#   inflating: deep-learning-v2-pytorch-master/keras/transfer-learning/transfer_learning.ipynb
#    creating: deep-learning-v2-pytorch-master/project-bikesharing/
#    creating: deep-learning-v2-pytorch-master/project-bikesharing/.udacity-pa/
#   inflating: deep-learning-v2-pytorch-master/project-bikesharing/.udacity-pa/projects.py
#    creating: deep-learning-v2-pytorch-master/project-bikesharing/Bike-Sharing-Dataset/
#   inflating: deep-learning-v2-pytorch-master/project-bikesharing/Bike-Sharing-Dataset/Readme.txt
#   inflating: deep-learning-v2-pytorch-master/project-bikesharing/Bike-Sharing-Dataset/day.csv
#   inflating: deep-learning-v2-pytorch-master/project-bikesharing/Bike-Sharing-Dataset/hour.csv
#   inflating: deep-learning-v2-pytorch-master/project-bikesharing/Your_first_neural_network.ipynb
#    creating: deep-learning-v2-pytorch-master/project-bikesharing/assets/
#   inflating: deep-learning-v2-pytorch-master/project-bikesharing/assets/neural_network.png
#   inflating: deep-learning-v2-pytorch-master/project-bikesharing/my_answers.py
#    creating: deep-learning-v2-pytorch-master/project-dog-classification/
#   inflating: deep-learning-v2-pytorch-master/project-dog-classification/README.md
#   inflating: deep-learning-v2-pytorch-master/project-dog-classification/dog_app.ipynb
#    creating: deep-learning-v2-pytorch-master/project-dog-classification/haarcascades/
#   inflating: deep-learning-v2-pytorch-master/project-dog-classification/haarcascades/haarcascade_frontalface_alt.xml
#    creating: deep-learning-v2-pytorch-master/project-dog-classification/images/
#   inflating: deep-learning-v2-pytorch-master/project-dog-classification/images/American_water_spaniel_00648.jpg
#   inflating: deep-learning-v2-pytorch-master/project-dog-classification/images/Brittany_02625.jpg
#   inflating: deep-learning-v2-pytorch-master/project-dog-classification/images/Curly-coated_retriever_03896.jpg
#   inflating: deep-learning-v2-pytorch-master/project-dog-classification/images/Labrador_retriever_06449.jpg
#   inflating: deep-learning-v2-pytorch-master/project-dog-classification/images/Labrador_retriever_06455.jpg
#   inflating: deep-learning-v2-pytorch-master/project-dog-classification/images/Labrador_retriever_06457.jpg
#   inflating: deep-learning-v2-pytorch-master/project-dog-classification/images/Welsh_springer_spaniel_08203.jpg
#   inflating: deep-learning-v2-pytorch-master/project-dog-classification/images/sample_cnn.png
#   inflating: deep-learning-v2-pytorch-master/project-dog-classification/images/sample_dog_output.png
#   inflating: deep-learning-v2-pytorch-master/project-dog-classification/images/sample_human_output.png
#    creating: deep-learning-v2-pytorch-master/project-face-generation/
#    creating: deep-learning-v2-pytorch-master/project-face-generation/assets/
#   inflating: deep-learning-v2-pytorch-master/project-face-generation/assets/processed_face_data.png
#   inflating: deep-learning-v2-pytorch-master/project-face-generation/dlnd_face_generation.ipynb
#   inflating: deep-learning-v2-pytorch-master/project-face-generation/problem_unittests.py
#    creating: deep-learning-v2-pytorch-master/project-tv-script-generation/
#    creating: deep-learning-v2-pytorch-master/project-tv-script-generation/data/
#   inflating: deep-learning-v2-pytorch-master/project-tv-script-generation/data/Seinfeld_Scripts.txt
#   inflating: deep-learning-v2-pytorch-master/project-tv-script-generation/dlnd_tv_script_generation.ipynb
#   inflating: deep-learning-v2-pytorch-master/project-tv-script-generation/helper.py
#   inflating: deep-learning-v2-pytorch-master/project-tv-script-generation/problem_unittests.py
#    creating: deep-learning-v2-pytorch-master/recurrent-neural-networks/
#    creating: deep-learning-v2-pytorch-master/recurrent-neural-networks/char-rnn/
#   inflating: deep-learning-v2-pytorch-master/recurrent-neural-networks/char-rnn/Character_Level_RNN_Exercise.ipynb
#   inflating: deep-learning-v2-pytorch-master/recurrent-neural-networks/char-rnn/Character_Level_RNN_Solution.ipynb
#    creating: deep-learning-v2-pytorch-master/recurrent-neural-networks/char-rnn/assets/
#   inflating: deep-learning-v2-pytorch-master/recurrent-neural-networks/char-rnn/assets/charRNN.png
#   inflating: deep-learning-v2-pytorch-master/recurrent-neural-networks/char-rnn/assets/charRNN@0.5x.png
#   inflating: deep-learning-v2-pytorch-master/recurrent-neural-networks/char-rnn/assets/charseq.jpeg
#   inflating: deep-learning-v2-pytorch-master/recurrent-neural-networks/char-rnn/assets/sequence_batching.png
#   inflating: deep-learning-v2-pytorch-master/recurrent-neural-networks/char-rnn/assets/sequence_batching@1x.png
#   inflating: deep-learning-v2-pytorch-master/recurrent-neural-networks/char-rnn/assets/sequence_batching_ex.png
#    creating: deep-learning-v2-pytorch-master/recurrent-neural-networks/char-rnn/data/
#   inflating: deep-learning-v2-pytorch-master/recurrent-neural-networks/char-rnn/data/anna.txt
#    creating: deep-learning-v2-pytorch-master/recurrent-neural-networks/time-series/
#   inflating: deep-learning-v2-pytorch-master/recurrent-neural-networks/time-series/Simple_RNN.ipynb
#    creating: deep-learning-v2-pytorch-master/recurrent-neural-networks/time-series/assets/
#   inflating: deep-learning-v2-pytorch-master/recurrent-neural-networks/time-series/assets/time_prediction.png
#   inflating: deep-learning-v2-pytorch-master/requirements.txt
#    creating: deep-learning-v2-pytorch-master/sentiment-analysis-network/
#   inflating: deep-learning-v2-pytorch-master/sentiment-analysis-network/Sentiment_Classification_Projects.ipynb
#   inflating: deep-learning-v2-pytorch-master/sentiment-analysis-network/Sentiment_Classification_Solutions.ipynb
#   inflating: deep-learning-v2-pytorch-master/sentiment-analysis-network/Sentiment_Classification_Solutions_2_Better_Weight_Initialization.ipynb
#   inflating: deep-learning-v2-pytorch-master/sentiment-analysis-network/labels.txt
#   inflating: deep-learning-v2-pytorch-master/sentiment-analysis-network/reviews.txt
#   inflating: deep-learning-v2-pytorch-master/sentiment-analysis-network/sentiment_network.png
#   inflating: deep-learning-v2-pytorch-master/sentiment-analysis-network/sentiment_network_2.png
#   inflating: deep-learning-v2-pytorch-master/sentiment-analysis-network/sentiment_network_pos.png
#   inflating: deep-learning-v2-pytorch-master/sentiment-analysis-network/sentiment_network_sparse.png
#   inflating: deep-learning-v2-pytorch-master/sentiment-analysis-network/sentiment_network_sparse_2.png
#    creating: deep-learning-v2-pytorch-master/sentiment-rnn/
#   inflating: deep-learning-v2-pytorch-master/sentiment-rnn/Sentiment_RNN_Exercise.ipynb
#   inflating: deep-learning-v2-pytorch-master/sentiment-rnn/Sentiment_RNN_Solution.ipynb
#    creating: deep-learning-v2-pytorch-master/sentiment-rnn/assets/
#   inflating: deep-learning-v2-pytorch-master/sentiment-rnn/assets/network_diagram.png
#   inflating: deep-learning-v2-pytorch-master/sentiment-rnn/assets/outliers_padding_ex.png
#   inflating: deep-learning-v2-pytorch-master/sentiment-rnn/assets/reviews_ex.png
#    creating: deep-learning-v2-pytorch-master/sentiment-rnn/data/
#   inflating: deep-learning-v2-pytorch-master/sentiment-rnn/data/labels.txt
#   inflating: deep-learning-v2-pytorch-master/sentiment-rnn/data/reviews.txt
#    creating: deep-learning-v2-pytorch-master/style-transfer/
#   inflating: deep-learning-v2-pytorch-master/style-transfer/Style_Transfer_Exercise.ipynb
#   inflating: deep-learning-v2-pytorch-master/style-transfer/Style_Transfer_Solution.ipynb
#    creating: deep-learning-v2-pytorch-master/style-transfer/images/
#   inflating: deep-learning-v2-pytorch-master/style-transfer/images/ben_passmore.jpg
#   inflating: deep-learning-v2-pytorch-master/style-transfer/images/delaunay.jpg
#   inflating: deep-learning-v2-pytorch-master/style-transfer/images/hockney.jpg
#  extracting: deep-learning-v2-pytorch-master/style-transfer/images/janelle.png
#   inflating: deep-learning-v2-pytorch-master/style-transfer/images/kahlo.jpg
#   inflating: deep-learning-v2-pytorch-master/style-transfer/images/magritte.jpg
#   inflating: deep-learning-v2-pytorch-master/style-transfer/images/octavia.jpg
#   inflating: deep-learning-v2-pytorch-master/style-transfer/images/octopus.jpg
#   inflating: deep-learning-v2-pytorch-master/style-transfer/images/sotomayor.jpg
#   inflating: deep-learning-v2-pytorch-master/style-transfer/images/space_needle.jpg
#    creating: deep-learning-v2-pytorch-master/style-transfer/notebook_ims/
#   inflating: deep-learning-v2-pytorch-master/style-transfer/notebook_ims/style_tx_cat.png
#   inflating: deep-learning-v2-pytorch-master/style-transfer/notebook_ims/vgg19_convlayers.png
#    creating: deep-learning-v2-pytorch-master/tensorflow/
#    creating: deep-learning-v2-pytorch-master/tensorflow/intro-to-tensorflow/
#   inflating: deep-learning-v2-pytorch-master/tensorflow/intro-to-tensorflow/environment.yml
#   inflating: deep-learning-v2-pytorch-master/tensorflow/intro-to-tensorflow/environment_win.yml
#    creating: deep-learning-v2-pytorch-master/tensorflow/intro-to-tensorflow/image/
#   inflating: deep-learning-v2-pytorch-master/tensorflow/intro-to-tensorflow/image/Learn_Rate_Tune_Image.png
#   inflating: deep-learning-v2-pytorch-master/tensorflow/intro-to-tensorflow/image/Mean_Variance_Image.png
#   inflating: deep-learning-v2-pytorch-master/tensorflow/intro-to-tensorflow/image/network_diagram.png
#   inflating: deep-learning-v2-pytorch-master/tensorflow/intro-to-tensorflow/image/notmnist.png
#   inflating: deep-learning-v2-pytorch-master/tensorflow/intro-to-tensorflow/intro_to_tensorflow.ipynb
#   inflating: deep-learning-v2-pytorch-master/tensorflow/intro-to-tensorflow/intro_to_tensorflow_solution.ipynb
#  extracting: deep-learning-v2-pytorch-master/tensorflow/intro-to-tensorflow/requirements.txt
#    creating: deep-learning-v2-pytorch-master/transfer-learning/
#   inflating: deep-learning-v2-pytorch-master/transfer-learning/Transfer_Learning_Exercise.ipynb
#   inflating: deep-learning-v2-pytorch-master/transfer-learning/Transfer_Learning_Solution.ipynb
#    creating: deep-learning-v2-pytorch-master/transfer-learning/notebook_ims/
#   inflating: deep-learning-v2-pytorch-master/transfer-learning/notebook_ims/vgg_16_architecture.png
#    creating: deep-learning-v2-pytorch-master/weight-initialization/
#   inflating: deep-learning-v2-pytorch-master/weight-initialization/helpers.py
#    creating: deep-learning-v2-pytorch-master/weight-initialization/notebook_ims/
#   inflating: deep-learning-v2-pytorch-master/weight-initialization/notebook_ims/loss_comparison_ex.png
#   inflating: deep-learning-v2-pytorch-master/weight-initialization/notebook_ims/neural_net.png
#   inflating: deep-learning-v2-pytorch-master/weight-initialization/notebook_ims/neuron_weights.png
#   inflating: deep-learning-v2-pytorch-master/weight-initialization/weight_initialization_exercise.ipynb
#   inflating: deep-learning-v2-pytorch-master/weight-initialization/weight_initialization_solution.ipynb
#    creating: deep-learning-v2-pytorch-master/word2vec-embeddings/
#   inflating: deep-learning-v2-pytorch-master/word2vec-embeddings/Negative_Sampling_Exercise.ipynb
#   inflating: deep-learning-v2-pytorch-master/word2vec-embeddings/Negative_Sampling_Solution.ipynb
#   inflating: deep-learning-v2-pytorch-master/word2vec-embeddings/Skip_Grams_Exercise.ipynb
#   inflating: deep-learning-v2-pytorch-master/word2vec-embeddings/Skip_Grams_Solution.ipynb
#    creating: deep-learning-v2-pytorch-master/word2vec-embeddings/assets/
#   inflating: deep-learning-v2-pytorch-master/word2vec-embeddings/assets/context_drink.png
#   inflating: deep-learning-v2-pytorch-master/word2vec-embeddings/assets/lookup_matrix.png
#   inflating: deep-learning-v2-pytorch-master/word2vec-embeddings/assets/neg_sampling_loss.png
#   inflating: deep-learning-v2-pytorch-master/word2vec-embeddings/assets/one_hot_encoding.png
#   inflating: deep-learning-v2-pytorch-master/word2vec-embeddings/assets/skip_gram_arch.png
#   inflating: deep-learning-v2-pytorch-master/word2vec-embeddings/assets/tokenize_lookup.png
#   inflating: deep-learning-v2-pytorch-master/word2vec-embeddings/assets/two_vectors.png
#   inflating: deep-learning-v2-pytorch-master/word2vec-embeddings/assets/vector_distance.png
#   inflating: deep-learning-v2-pytorch-master/word2vec-embeddings/assets/word2vec_architectures.png
#    creating: deep-learning-v2-pytorch-master/word2vec-embeddings/data/
#   inflating: deep-learning-v2-pytorch-master/word2vec-embeddings/data/download_data.txt
#   inflating: deep-learning-v2-pytorch-master/word2vec-embeddings/utils.py

# %%
from os.path import exists
from wheel.pep425tags import get_abbr_impl, get_impl_ver, get_abi_tag
platform = '{}{}-{}'.format(get_abbr_impl(), get_impl_ver(), get_abi_tag())
cuda_output = !ldconfig -p|grep cudart.so|sed -e 's/.*\.\([0-9]*\)\.\([0-9]*\)$/cu\1\2/'
accelerator = cuda_output[0] if exists('/dev/nvidia0') else 'cpu'

# !pip install -q http://download.pytorch.org/whl/{accelerator}/torch-0.4.1-{platform}-linux_x86_64.whl torchvision

# %%
# import resources
# %matplotlib inline

import matplotlib.pyplot as plt
import numpy as np

# !pip install Pillow==4.0.0
# !pip install PIL
# !pip install image
import PIL
from PIL import Image

import torch
import torch.optim as optim
from torchvision import transforms, models
# Out:
# Requirement already satisfied: Pillow==4.0.0 in /usr/local/lib/python3.6/dist-packages (4.0.0)
# Requirement already satisfied: olefile in /usr/local/lib/python3.6/dist-packages (from Pillow==4.0.0) (0.46)
# Collecting PIL
#   Could not find a version that satisfies the requirement PIL (from versions: )
# No matching distribution found for PIL
# Requirement already satisfied: image in /usr/local/lib/python3.6/dist-packages (1.5.27)
# Requirement already satisfied: django in /usr/local/lib/python3.6/dist-packages (from image) (2.1.4)
# Requirement already satisfied: pillow in /usr/local/lib/python3.6/dist-packages (from image) (4.0.0)
# Requirement already satisfied: pytz in /usr/local/lib/python3.6/dist-packages (from django->image) (2018.7)
# Requirement already satisfied: olefile in /usr/local/lib/python3.6/dist-packages (from pillow->image) (0.46)

# %% [markdown]
# ## Load in VGG19 (features)
#
# VGG19 is split into two portions:
# * `vgg19.features`, which are all the convolutional and pooling layers
# * `vgg19.classifier`, which are the three linear, classifier layers at the end
#
# We only need the `features` portion, which we're going to load in and "freeze" the weights of, below.

# %%
# get the "features" portion of VGG19 (we will not need the "classifier" portion)
vgg = models.vgg19(pretrained=True).features

# freeze all VGG parameters since we're only optimizing the target image
for param in vgg.parameters():
    param.requires_grad_(False)

# %%
# move the model to GPU, if available
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

vgg.to(device)
# Out:
# Sequential(
#   (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (1): ReLU(inplace)
#   (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (3): ReLU(inplace)
#   (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (5): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (6): ReLU(inplace)
#   (7): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (8): ReLU(inplace)
#   (9): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (10): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (11): ReLU(inplace)
#   (12): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (13): ReLU(inplace)
#   (14): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (15): ReLU(inplace)
#   (16): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (17): ReLU(inplace)
#   (18): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (19): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (20): ReLU(inplace)
#   (21): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (22): ReLU(inplace)
#   (23): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (24): ReLU(inplace)
#   (25): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (26): ReLU(inplace)
#   (27): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (28): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (29): ReLU(inplace)
#   (30): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (31): ReLU(inplace)
#   (32): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (33): ReLU(inplace)
#   (34): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (35): ReLU(inplace)
#   (36): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
# )

# %% [markdown]
# ### Load in Content and Style Images
#
# You can load in any images you want! Below, we've provided a helper function for loading in any type and size of image. The `load_image` function also converts images to normalized Tensors.
#
# Additionally, it will be easier to have smaller images and to squish the content and style images so that they are of the same size.

# %%
def load_image(img_path, max_size=400, shape=None):
    ''' Load in and transform an image, making sure the image
       is <= 400 pixels in the x-y dims.'''
    
    image = Image.open(img_path).convert('RGB')
    
    # large images will slow down processing
    if max(image.size) > max_size:
        size = max_size
    else:
        size = max(image.size)
    
    if shape is not None:
        size = shape
        
    in_transform = transforms.Compose([
                        transforms.Resize(size),
                        transforms.ToTensor(),
                        transforms.Normalize((0.485, 0.456, 0.406), 
                                             (0.229, 0.224, 0.225))])

    # discard the transparent, alpha channel (that's the :3) and add the batch dimension
    image = in_transform(image)[:3,:,:].unsqueeze(0)
    
    return image

# %% [markdown]
# Next, I'm loading in images by file name and forcing the style image to be the same size as the content image.

# %%
# load in content and style image
content = load_image('images/octopus.jpg').to(device)
# Resize style to match content, makes code easier
style = load_image('images/kahlo.jpg', shape=content.shape[-2:]).to(device)

# %%
# helper function for un-normalizing an image 
# and converting it from a Tensor image to a NumPy image for display
def im_convert(tensor):
    """ Display a tensor as an image. """
    
    image = tensor.to("cpu").clone().detach()
    image = image.numpy().squeeze()
    image = image.transpose(1,2,0)
    image = image * np.array((0.229, 0.224, 0.225)) + np.array((0.485, 0.456, 0.406))
    image = image.clip(0, 1)

    return image

# %%
# display the images
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(20, 10))
# content and style ims side-by-side
ax1.imshow(im_convert(content))
ax2.imshow(im_convert(style))

# %% [markdown]
# ---
# ## VGG19 Layers
#
# To get the content and style representations of an image, we have to pass an image forward throug the VGG19 network until we get to the desired layer(s) and then get the output from that layer.

# %%
# print out VGG19 structure so you can see the names of various layers
# print(vgg)

# %% [markdown]
# ## Content and Style Features
#
# Below, complete the mapping of layer names to the names found in the paper for the _content representation_ and the _style representation_.

# %%
def get_features(image, model, layers=None):
    """ Run an image forward through a model and get the features for 
        a set of layers. Default layers are for VGGNet matching Gatys et al (2016)
    """
    
    ## TODO: Complete mapping layer names of PyTorch's VGGNet to names from the paper
    ## Need the layers for the content and style representations of an image
    if layers is None:
        layers = {'0': 'conv1_1',
                  '5': 'conv2_1', 
                  '10': 'conv3_1', 
                  '19': 'conv4_1',
                  '21': 'conv4_2',  ## content representation
                  '28': 'conv5_1'}
        
    features = {}
    x = image
    # model._modules is a dictionary holding each module in the model
    for name, layer in model._modules.items():
        x = layer(x)
        if name in layers:
            features[layers[name]] = x
            
    return features

# %% [markdown]
# ---
# ## Gram Matrix
#
# The output of every convolutional layer is a Tensor with dimensions associated with the `batch_size`, a depth, `d` and some height and width (`h`, `w`). The Gram matrix of a convolutional layer can be calculated as follows:
# * Get the depth, height, and width of a tensor using `batch_size, d, h, w = tensor.size`
# * Reshape that tensor so that the spatial dimensions are flattened
# * Calculate the gram matrix by multiplying the reshaped tensor by it's transpose
#
# *Note: You can multiply two matrices using `torch.mm(matrix1, matrix2)`.*

# %%
def gram_matrix(tensor):
    """ Calculate the Gram Matrix of a given tensor 
        Gram Matrix: https://en.wikipedia.org/wiki/Gramian_matrix
    """
    
    # get the batch_size, depth, height, and width of the Tensor
    _, d, h, w = tensor.size()
    
    # reshape so we're multiplying the features for each channel
    tensor = tensor.view(d, h * w)
    
    # calculate the gram matrix
    gram = torch.mm(tensor, tensor.t())
    
    return gram

# %% [markdown]
# ## Putting it all Together
#
# Now that we've written functions for extracting features and computing the gram matrix of a given convolutional layer; let's put all these pieces together! We'll extract our features from our images and calculate the gram matrices for each layer in our style representation.

# %%
# get content and style features only once before training
content_features = get_features(content, vgg)
style_features = get_features(style, vgg)

# calculate the gram matrices for each layer of our style representation
style_grams = {layer: gram_matrix(style_features[layer]) for layer in style_features}

# create a third "target" image and prep it for change
# it is a good idea to start of with the target as a copy of our *content* image
# then iteratively change its style
target = content.clone().requires_grad_(True).to(device)

# %% [markdown]
# ---
# ## Loss and Weights
#
# #### Individual Layer Style Weights
#
# Below, you are given the option to weight the style representation at each relevant layer. It's suggested that you use a range between 0-1 to weight these layers. By weighting earlier layers (`conv1_1` and `conv2_1`) more, you can expect to get _larger_ style artifacts in your resulting, target image. Should you choose to weight later layers, you'll get more emphasis on smaller features. This is because each layer is a different size and together they create a multi-scale style representation!
#
# #### Content and Style Weight
#
# Just like in the paper, we define an alpha (`content_weight`) and a beta (`style_weight`). This ratio will affect how _stylized_ your final image is. It's recommended that you leave the content_weight = 1 and set the style_weight to achieve the ratio you want.

# %%
# weights for each style layer 
# weighting earlier layers more will result in *larger* style artifacts
# notice we are excluding `conv4_2` our content representation
style_weights = {'conv1_1': 1.,
                 'conv2_1': 0.75,
                 'conv3_1': 0.2,
                 'conv4_1': 0.2,
                 'conv5_1': 0.2}

content_weight = 1  # alpha
style_weight = 1e6  # beta

# %% [markdown]
# ## Updating the Target & Calculating Losses
#
# You'll decide on a number of steps for which to update your image, this is similar to the training loop that you've seen before, only we are changing our _target_ image and nothing else about VGG19 or any other image. Therefore, the number of steps is really up to you to set! **I recommend using at least 2000 steps for good results.** But, you may want to start out with fewer steps if you are just testing out different weight values or experimenting with different images.
#
# Inside the iteration loop, you'll calculate the content and style losses and update your target image, accordingly.
#
# #### Content Loss
#
# The content loss will be the mean squared difference between the target and content features at layer `conv4_2`. This can be calculated as follows:
# ```
# content_loss = torch.mean((target_features['conv4_2'] - content_features['conv4_2'])**2)
# ```
#
# #### Style Loss
#
# The style loss is calculated in a similar way, only you have to iterate through a number of layers, specified by name in our dictionary `style_weights`.
# > You'll calculate the gram matrix for the target image, `target_gram` and style image `style_gram` at each of these layers and compare those gram matrices, calculating the `layer_style_loss`.
# > Later, you'll see that this value is normalized by the size of the layer.
#
# #### Total Loss
#
# Finally, you'll create the total loss by adding up the style and content losses and weighting them with your specified alpha and beta!
#
# Intermittently, we'll print out this loss; don't be alarmed if the loss is very large. It takes some time for an image's style to change and you should focus on the appearance of your target image rather than any loss value. Still, you should see that this loss decreases over some number of iterations.

# %%
# for displaying the target image, intermittently
show_every = 400

# iteration hyperparameters
optimizer = optim.Adam([target], lr=0.001)
steps = 2000  # decide how many iterations to update your image

for ii in range(1, steps+1):
    
    # get the features from your target image
    target_features = get_features(target, vgg)
    
    # the content loss
    content_loss = torch.mean((target_features['conv4_2'] - content_features['conv4_2'])**2)
    
    # the style loss
    # initialize the style loss to 0
    style_loss = 0
    # then add to it for each layer's gram matrix loss
    for layer in style_weights:
        # get the "target" style representation for the layer
        target_feature = target_features[layer]
        target_gram = gram_matrix(target_feature)
        _, d, h, w = target_feature.shape
        # get the "style" style representation
        style_gram = style_grams[layer]
        # the style loss for one layer, weighted appropriately
        layer_style_loss = style_weights[layer] * torch.mean((target_gram - style_gram)**2)
        # add to the style loss
        style_loss += layer_style_loss / (d * h * w)
        
    # calculate the *total* loss
    total_loss = content_weight * content_loss + style_weight * style_loss
    
    # update your target image
    optimizer.zero_grad()
    total_loss.backward()
    optimizer.step()
    
    # display intermediate images and print the loss
    if  ii % show_every == 0:
        print('Total loss: ', total_loss.item())
        plt.imshow(im_convert(target))
        plt.show()
# Out:
# Total loss:  51138636.0
# Total loss:  18071158.0
# Total loss:  8584711.0
# Total loss:  5069543.0
# Total loss:  3493860.0

# %% [markdown]
# ## Display the Target Image

# %%
# display content and final, target image
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(20, 10))
ax1.imshow(im_convert(content))
ax2.imshow(im_convert(target))
plt.imsave('test.png', im_convert(target))
